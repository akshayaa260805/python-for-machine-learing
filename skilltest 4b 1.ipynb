# %%
import pandas as pd

data = {
'Product': ['Laptop','Smartphone','Tablet','Monitor','Keyboard'],
'Price': [1200,800,300,150,50],
'Quantity': [10,20,15,25,50]
}

df = pd.DataFrame(data)

# Display data
print("Inventory Data")
print(df)

# Operation 1: Average price
print("Average Price:", df['Price'].mean())

# Operation 2: Maximum price
print("Maximum Price:", df['Price'].max())

# Operation 3: Minimum quantity
print("Minimum Quantity:", df['Quantity'].min())

# Operation 4: Total quantity
print("Total Quantity:", df['Quantity'].sum())

# Operation 5: Total inventory value
df['Total Value'] = df['Price'] * df['Quantity']
print("Total Inventory Value:", df['Total Value'].sum())
# Out:
# Inventory Data
#       Product  Price  Quantity
# 0      Laptop   1200        10
# 1  Smartphone    800        20
# 2      Tablet    300        15
# 3     Monitor    150        25
# 4    Keyboard     50        50
# Average Price: 500.0
# Maximum Price: 1200
# Minimum Quantity: 10
# Total Quantity: 120
# Total Inventory Value: 38750
