# %%
import pandas as pd
import numpy as np
from datetime import datetime
dates = [datetime(2020,1,5),
datetime(2020,1,10),
datetime(2020,1,15),
datetime(2020,1,20),
datetime(2020,1,25)]
ts = pd.Series(np.random.randn(5), index=dates)
print("\nWith this date object, create a series with datetime index:\n",ts)
# Out:
# With this date object, create a series with datetime index:
#  2020-01-05    0.397925
# 2020-01-10   -0.067331
# 2020-01-15   -0.723007
# 2020-01-20    0.320496
# 2020-01-25    2.039202
# dtype: float64

# %%
res=ts.truncate(after="1/15/2020")
print("\nTruncate method to truncate datetime series \n", res)
# Out:
# Truncate method to truncate datetime series
#  2020-01-05    0.397925
# 2020-01-10   -0.067331
# 2020-01-15   -0.723007
# dtype: float64

# %%
da=pd.date_range("10/1/2022", periods=10, freq="W-SUN")
print("\nDate range with day periods.\n",da)
# Out:
# Date range with day periods.
#  DatetimeIndex(['2022-10-02', '2022-10-09', '2022-10-16', '2022-10-23',
#                '2022-10-30', '2022-11-06', '2022-11-13', '2022-11-20',
#                '2022-11-27', '2022-12-04'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
date=pd.DatetimeIndex(["1/1/2020","1/2/2020","1/2/2020","1/2/2020","1/3/2020"])
ts1=pd.Series(np.arange(5), index=date)
print("\nDuplicate datetime index:\n",ts1)
# Out:
# Duplicate datetime index:
#  2020-01-01    0
# 2020-01-02    1
# 2020-01-02    2
# 2020-01-02    3
# 2020-01-03    4
# dtype: int32

# %%
group=ts1.groupby(level=0)
print("\nRepeated date counts:\n",group.count())
# Out:
# Repeated date counts:
#  2020-01-01    1
# 2020-01-02    3
# 2020-01-03    1
# dtype: int64

# %%
long_df=pd.DataFrame(np.random.randn(10,4),index=da,columns=list("ABCD"))
print("\nMulti-column DataFrame with datatime index:\n",long_df)
# Out:
# Multi-column DataFrame with datatime index:
#                     A         B         C         D
# 2022-10-02 -0.195535 -0.833854  1.224569  0.194724
# 2022-10-09 -0.443303  1.147180  0.034894  0.300068
# 2022-10-16 -1.222386 -0.503998  0.037130 -0.138195
# 2022-10-23  1.909455 -0.723005 -0.449854 -0.994772
# 2022-10-30  1.659313 -1.284326  2.171347 -1.475193
# 2022-11-06  1.791738 -1.608858 -0.240640  1.072488
# 2022-11-13 -1.957044 -0.223876  2.420483  1.391416
# 2022-11-20 -0.353881 -0.086907  0.452573 -0.454535
# 2022-11-27  0.623175  0.570555  0.821726  1.208205
# 2022-12-04 -1.423519  1.884982  0.266806 -0.930861
